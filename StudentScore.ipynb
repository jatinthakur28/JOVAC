# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
file = 'score_updated.csv'  
df = pd.read_csv(file)

# %%
missing_values = df.isnull().sum()
print(f'Missing values:\n{missing_values}')
# Out:
# Missing values:
# Hours     0
# Scores    0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df.Hours,df.Scores,color='red',marker='*')
plt.title('Scatter Plot of Study Hours vs. Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Scores Obtained')
plt.grid(True)
plt.show()

# %%
X = df[['Hours']]  
y = df['Scores']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f'Intercept (theta_0): {model.intercept_}')
print(f'Coefficient (theta_1): {model.coef_[0]}')
# Out:
# Intercept (theta_0): 1.404560412917931
# Coefficient (theta_1): 10.052798249786854

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([46.64215254, 62.72662974, 16.48375779, 87.85862536, 84.84278589,
#        35.58407446, 93.89030431, 68.75830869, 98.91670344, 25.53127621,
#        19.49959726, 71.77414816, 44.63159289, 85.84806571, 81.82694641,
#        86.85334554, 52.67383149, 65.74246921, 51.66855166, 73.78470781])

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 2.914109599744455
# Mean Squared Error (MSE): 15.452320507034603
# Root Mean Squared Error (RMSE): 3.9309439714952186
# R-squared (R²): 0.9720586760928984

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_test, y_test, color='red',marker='*', label='Actual Scores')
plt.plot(X_test, y_pred, color='blue', label='Regression Line')
plt.title('Study Hours vs Scores')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.legend()
plt.grid(True)
plt.show()
